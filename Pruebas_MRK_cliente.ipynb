# %%
import streamlit as st
import pandas as pd
import pydeck as pdk
import hashlib
import glob
import streamlit.components.v1 as components
import plotly.graph_objects as go
import matplotlib.colors as mcolors
from parso.pgen2.generator import DFAPlan

# %%
# 📂 Ruta donde están los archivos
ruta_archivos = "reportes_clientes/*.xlsx"

# 🧾 Lista de todos los archivos que coincidan
archivos = glob.glob(ruta_archivos)

# 📊 Leer y concatenar todos los archivos (solo hoja 'Resumen ruta')
dfs = []

for archivo in archivos:
    try:
        df_temp = pd.read_excel(archivo, sheet_name="Reporte diario cliente")
        df_temp["Archivo"] = archivo  # opcional: para saber de qué archivo viene
        dfs.append(df_temp)
    except ValueError:
        print(f"⚠️ La hoja 'Resumen ruta' no se encontró en {archivo}")
    except Exception as e:
        print(f"❌ Error al leer {archivo}: {e}")

# Concatenar si hay data
if dfs:
    df_mrk = pd.concat(dfs, ignore_index=True)
    print("✅ Archivos combinados correctamente:", len(dfs))
else:
    print("⚠️ No se pudo leer ningún archivo válido.")
# Out:
# ✅ Archivos combinados correctamente: 43

# %%
df_mrk.to_parquet('concentrado_mrk_2025.parquet')

df_mrk
# Out:
#                      Zona                Región Gerencia Jefatura    Ruta  \
# 0         CENTRO-PACIFICO          TECAMACHALCO     NA01      NA6  NA0028
# 1         CENTRO-PACIFICO          TECAMACHALCO     NA01      NA6  NA0028
# 2         CENTRO-PACIFICO          TECAMACHALCO     NA01      NA6  NA0028
# 3         CENTRO-PACIFICO          TECAMACHALCO     NA01      NA6  NA0028
# 4         CENTRO-PACIFICO          TECAMACHALCO     NA01      NA6  NA0028
# ...                   ...                   ...      ...      ...     ...
# 11725678  CENTRO-PACIFICO  CHILAPA-CHILPANCINGO     HW01      HW1  HW0197
# 11725679  CENTRO-PACIFICO  CHILAPA-CHILPANCINGO     HW01      HW1  HW0199
# 11725680  CENTRO-PACIFICO              ACAPULCO     CJ01      CJ2  CJ0011
# 11725681  CENTRO-PACIFICO  CHILAPA-CHILPANCINGO     HV01      HV3  HV0103
# 11725682  CENTRO-PACIFICO  CHILAPA-CHILPANCINGO     HV01      HV3  HV0103
#
#           Id cliente                  Cliente                  Canal     GEC  \
# ...

# %%
from datetime import time

# 🕒 1. Detectar columnas con "(hr)"
cols_hr = [col for col in df_mrk.columns if '(hr)' in col]
print("Columnas a convertir:", cols_hr)

# 🧭 2. Normalizar y convertir
for col in cols_hr:
    # Si algún valor es datetime.time, conviértelo a string "HH:MM:SS"
    df_mrk[col] = df_mrk[col].apply(
        lambda x: x.strftime('%H:%M:%S') if isinstance(x, time) else x
    )
    # Luego convertir a timedelta
    df_mrk[col] = pd.to_timedelta(df_mrk[col], errors='coerce')

# 📊 Verificar
df_mrk.info()
# Out:
# Columnas a convertir: []
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11725683 entries, 0 to 11725682
# Data columns (total 31 columns):
#  #   Column                                 Dtype
# ---  ------                                 -----
#  0   Zona                                   object
#  1   Región                                 object
#  2   Gerencia                               object
#  3   Jefatura                               object
#  4   Ruta                                   object
#  5   Id cliente                             int64
#  6   Cliente                                object
#  7   Canal                                  object
#  8   GEC                                    object
#  9   Fecha                                  datetime64[ns]
#  10  Pedido                                 int64
#  11  Distancia de llegada al cliente (mts)  float64
#  12  Distancia de salida al cliente (mts)   float64
# ...

# %%
df_mrk.head()
# Out:
#               Zona        Región Gerencia Jefatura    Ruta  Id cliente  \
# 0  CENTRO-PACIFICO  TECAMACHALCO     NA01      NA6  NA0028         142
# 1  CENTRO-PACIFICO  TECAMACHALCO     NA01      NA6  NA0028         142
# 2  CENTRO-PACIFICO  TECAMACHALCO     NA01      NA6  NA0028         142
# 3  CENTRO-PACIFICO  TECAMACHALCO     NA01      NA6  NA0028         142
# 4  CENTRO-PACIFICO  TECAMACHALCO     NA01      NA6  NA0028         142
#
#                    Cliente Canal  GEC      Fecha  ...  Latitud del maestro  \
# 0  DISTRIBUIDORA LA PIEDAD   NaN  NaN 2025-02-01  ...                  0.0
# 1  DISTRIBUIDORA LA PIEDAD   NaN  NaN 2025-02-08  ...                  0.0
# 2  DISTRIBUIDORA LA PIEDAD   NaN  NaN 2025-02-03  ...                  0.0
# 3  DISTRIBUIDORA LA PIEDAD   NaN  NaN 2025-02-07  ...                  0.0
# 4  DISTRIBUIDORA LA PIEDAD   NaN  NaN 2025-02-05  ...                  0.0
#
#    Longitud del maestro  Tiempo de atencion Geoeficiencia fuera de frecuencia  \
# ...

# %%
df_catalogo = pd.read_csv('catalogo.csv', encoding='utf-8')
df_catalogo = df_catalogo[['Ruta','Jefatura','Tipo','Descripción Tipo','TPV','Región Comercial_Act 2026','Nombre UO']]

df_mrk_full = df_mrk.merge(how='left', right=df_catalogo, left_on='Ruta', right_on='Ruta')
df_mrk_full.head()
# Out:
#               Zona        Región Gerencia Jefatura_x    Ruta  Id cliente  \
# 0  CENTRO-PACIFICO  TECAMACHALCO     NA01        NA6  NA0028         142
# 1  CENTRO-PACIFICO  TECAMACHALCO     NA01        NA6  NA0028         142
# 2  CENTRO-PACIFICO  TECAMACHALCO     NA01        NA6  NA0028         142
# 3  CENTRO-PACIFICO  TECAMACHALCO     NA01        NA6  NA0028         142
# 4  CENTRO-PACIFICO  TECAMACHALCO     NA01        NA6  NA0028         142
#
#                    Cliente Canal  GEC      Fecha  ...  Pedido Digital  \
# 0  DISTRIBUIDORA LA PIEDAD   NaN  NaN 2025-02-01  ...               0
# 1  DISTRIBUIDORA LA PIEDAD   NaN  NaN 2025-02-08  ...               0
# 2  DISTRIBUIDORA LA PIEDAD   NaN  NaN 2025-02-03  ...               0
# 3  DISTRIBUIDORA LA PIEDAD   NaN  NaN 2025-02-07  ...               0
# 4  DISTRIBUIDORA LA PIEDAD   NaN  NaN 2025-02-05  ...               0
#
#    Pedido Omnicanal  Planeado Digital  \
# 0                 0                 1
# ...

# %%
df_mrk_cp = df_mrk_full[df_mrk_full['Zona'] == 'CENTRO-PACIFICO']
df_mrk_cp = df_mrk_cp[df_mrk_cp['Tipo'].isin(['PR', 'PCOP', 'FC', 'MA', 'PRTDC'])]
df_mrk_cp = df_mrk_cp.rename(columns={'Fecha': 'Fecha inicio'})

df_mrk_cp['Región'] = df_mrk_cp['Región'].where(
~df_mrk_cp['Tipo'].isin(['MA', 'PRTDC'])
).fillna(df_mrk_cp['Tipo'].replace({'MA': 'MAYORISTAS', 'PRTDC': 'MODERNO'}))
df_mrk_cp['Semana'] = df_mrk_cp['Fecha inicio'].dt.isocalendar().week

df_mrk_cp
# Out:
#                      Zona                Región Gerencia Jefatura_x    Ruta  \
# 0         CENTRO-PACIFICO          TECAMACHALCO     NA01        NA6  NA0028
# 1         CENTRO-PACIFICO          TECAMACHALCO     NA01        NA6  NA0028
# 2         CENTRO-PACIFICO          TECAMACHALCO     NA01        NA6  NA0028
# 3         CENTRO-PACIFICO          TECAMACHALCO     NA01        NA6  NA0028
# 4         CENTRO-PACIFICO          TECAMACHALCO     NA01        NA6  NA0028
# ...                   ...                   ...      ...        ...     ...
# 11725678  CENTRO-PACIFICO  CHILAPA-CHILPANCINGO     HW01        HW1  HW0197
# 11725679  CENTRO-PACIFICO  CHILAPA-CHILPANCINGO     HW01        HW1  HW0199
# 11725680  CENTRO-PACIFICO              ACAPULCO     CJ01        CJ2  CJ0011
# 11725681  CENTRO-PACIFICO  CHILAPA-CHILPANCINGO     HV01        HV3  HV0103
# 11725682  CENTRO-PACIFICO  CHILAPA-CHILPANCINGO     HV01        HV3  HV0103
#
# ...

# %%
df_mrk_cp['Tiempo de atencion'] = pd.to_timedelta(df_mrk_cp['Tiempo de atencion'], errors='coerce')
df_mrk_cp['Hora de llegada'] = pd.to_datetime(
    df_mrk_cp['Hora de llegada'], format='%H:%M:%S', errors='coerce'
)

# 📊 Crear el pivot con diferentes funciones de agregación
df_pivot_gec = df_mrk_cp.pivot_table(
    index=['Región Comercial_Act 2026','Nombre UO','Jefatura_y','Ruta','Descripción Tipo','Fecha inicio','GEC'],
    aggfunc={
        'Id cliente': 'count',
        'Geoeficiencia': 'sum',
        'Geoefectividad': 'sum',
        'Tiempo de atencion': 'mean',
        'Hora de llegada': 'min',
        'Pedido Omnicanal': 'sum',
    }
)

# 🔹 Convertir timedelta a HH:MM:SS sin días ni decimales
#df_pivot_gec['Tiempo de atencion'] = df_pivot_gec['Tiempo de atencion'].apply(
#    lambda x: str(x).split(' days ')[-1].split('.')[0] if pd.notnull(x) else None
#)

# 🔹 Mostrar solo HH:MM:SS en la hora de llegada
df_pivot_gec['Hora de llegada'] = df_pivot_gec['Hora de llegada'].dt.strftime('%H:%M:%S')

df_pivot_gec
# Out:
#                                                                                                       Geoefectividad  \
# Región Comercial_Act 2026 Nombre UO    Jefatura_y Ruta   Descripción Tipo   Fecha inicio GEC
# Acapulco                  Cayaco       CJ1        CJ0011 Preventa Comercial 2025-01-02   BRONCE                   15
#                                                                                          CUSTOMIZADO               3
#                                                                                          ORO                      11
#                                                                                          PLATA                    18
#                                                                             2025-01-03   BRONCE                    4
# ...                                                                                                              ...
# ...

# %%
df_pivot_gec = df_pivot_gec.reset_index()
df_pivot_gec.info()
df_pivot_gec
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 689197 entries, 0 to 689196
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Región Comercial_Act 2026  689197 non-null  object
#  1   Nombre UO                  689197 non-null  object
#  2   Jefatura_y                 689197 non-null  object
#  3   Ruta                       689197 non-null  object
#  4   Descripción Tipo           689197 non-null  object
#  5   Fecha inicio               689197 non-null  datetime64[ns]
#  6   GEC                        689197 non-null  object
#  7   Geoefectividad             689197 non-null  int64
#  8   Geoeficiencia              689197 non-null  int64
#  9   Hora de llegada            689197 non-null  object
#  10  Id cliente                 689197 non-null  int64
#  11  Pedido Omnicanal           689197 non-null  int64
#  12  Tiempo de atencion         689197 non-null  timedelta64[ns]
# ...

# %%
df_final_cliente = df_pivot_gec[['Fecha inicio','Región Comercial_Act 2026','Nombre UO','Jefatura_y','Ruta','Descripción Tipo','GEC','Id cliente','Geoeficiencia','Geoefectividad','Hora de llegada','Tiempo de atencion','Pedido Omnicanal']]

df_final_cliente = df_final_cliente.rename(columns={'Jefatura_y': 'Jefatura'})

df_final_cliente.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 689197 entries, 0 to 689196
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Fecha inicio               689197 non-null  datetime64[ns]
#  1   Región Comercial_Act 2026  689197 non-null  object
#  2   Nombre UO                  689197 non-null  object
#  3   Jefatura                   689197 non-null  object
#  4   Ruta                       689197 non-null  object
#  5   Descripción Tipo           689197 non-null  object
#  6   GEC                        689197 non-null  object
#  7   Id cliente                 689197 non-null  int64
#  8   Geoeficiencia              689197 non-null  int64
#  9   Geoefectividad             689197 non-null  int64
#  10  Hora de llegada            689197 non-null  object
#  11  Tiempo de atencion         689197 non-null  timedelta64[ns]
#  12  Pedido Omnicanal           689197 non-null  int64
# ...

# %%
df_final_cliente.to_parquet('bdd_mrk_cp_gec.parquet')

# %%
df_mrk_cp
# Out:
#                      Zona                Región Gerencia Jefatura_x    Ruta  \
# 0         CENTRO-PACIFICO          TECAMACHALCO     NA01        NA6  NA0028
# 1         CENTRO-PACIFICO          TECAMACHALCO     NA01        NA6  NA0028
# 2         CENTRO-PACIFICO          TECAMACHALCO     NA01        NA6  NA0028
# 3         CENTRO-PACIFICO          TECAMACHALCO     NA01        NA6  NA0028
# 4         CENTRO-PACIFICO          TECAMACHALCO     NA01        NA6  NA0028
# ...                   ...                   ...      ...        ...     ...
# 11725678  CENTRO-PACIFICO  CHILAPA-CHILPANCINGO     HW01        HW1  HW0197
# 11725679  CENTRO-PACIFICO  CHILAPA-CHILPANCINGO     HW01        HW1  HW0199
# 11725680  CENTRO-PACIFICO              ACAPULCO     CJ01        CJ2  CJ0011
# 11725681  CENTRO-PACIFICO  CHILAPA-CHILPANCINGO     HV01        HV3  HV0103
# 11725682  CENTRO-PACIFICO  CHILAPA-CHILPANCINGO     HV01        HV3  HV0103
#
# ...

# %%
df_class_clientes = pd.read_csv('Class_Clientes.csv', encoding='utf-8')
df_class_clientes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 444 entries, 0 to 443
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Cliente              444 non-null    int64
#  1   Recurrencia Digital  444 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 7.1+ KB

# %%
df_mrk_cp_class = df_mrk_cp.merge(how='left',right=df_class_clientes,left_on='Id cliente',right_on='Cliente')
df_mrk_cp_class = df_mrk_cp_class.drop(columns=['Cliente_y'])
df_mrk_cp_class['Recurrencia Digital'] = df_mrk_cp_class['Recurrencia Digital'].fillna("No")
df_mrk_cp_class
# Out:
#                      Zona                Región Gerencia Jefatura_x    Ruta  \
# 0         CENTRO-PACIFICO          TECAMACHALCO     NA01        NA6  NA0028
# 1         CENTRO-PACIFICO          TECAMACHALCO     NA01        NA6  NA0028
# 2         CENTRO-PACIFICO          TECAMACHALCO     NA01        NA6  NA0028
# 3         CENTRO-PACIFICO          TECAMACHALCO     NA01        NA6  NA0028
# 4         CENTRO-PACIFICO          TECAMACHALCO     NA01        NA6  NA0028
# ...                   ...                   ...      ...        ...     ...
# 11596400  CENTRO-PACIFICO  CHILAPA-CHILPANCINGO     HW01        HW1  HW0197
# 11596401  CENTRO-PACIFICO  CHILAPA-CHILPANCINGO     HW01        HW1  HW0199
# 11596402  CENTRO-PACIFICO              ACAPULCO     CJ01        CJ2  CJ0011
# 11596403  CENTRO-PACIFICO  CHILAPA-CHILPANCINGO     HV01        HV3  HV0103
# 11596404  CENTRO-PACIFICO  CHILAPA-CHILPANCINGO     HV01        HV3  HV0103
#
# ...

# %%
# 📊 Crear el pivot con diferentes funciones de agregación
df_pivot_class = df_mrk_cp_class.pivot_table(
    index=['Región Comercial_Act 2026','Nombre UO','Jefatura_y','Ruta','Descripción Tipo','Fecha inicio','Recurrencia Digital'],
    aggfunc={
        'Id cliente': 'count',
        'Geoeficiencia': 'sum',
        'Geoefectividad': 'sum',
        'Tiempo de atencion': 'mean',
        'Hora de llegada': 'min',
        'Pedido Omnicanal': 'sum',
    }
)

# 🔹 Mostrar solo HH:MM:SS en la hora de llegada
df_pivot_class['Hora de llegada'] = df_pivot_class['Hora de llegada'].dt.strftime('%H:%M:%S')
df_pivot_class = df_pivot_class.reset_index()
df_pivot_class
# Out:
#        Región Comercial_Act 2026     Nombre UO Jefatura_y    Ruta  \
# 0                       Acapulco        Cayaco        CJ1  CJ0011
# 1                       Acapulco        Cayaco        CJ1  CJ0011
# 2                       Acapulco        Cayaco        CJ1  CJ0011
# 3                       Acapulco        Cayaco        CJ1  CJ0011
# 4                       Acapulco        Cayaco        CJ1  CJ0011
# ...                          ...           ...        ...     ...
# 247805              Tecamachalco  Tecamachalco        NAB  NAM002
# 247806              Tecamachalco  Tecamachalco        NAB  NAM002
# 247807              Tecamachalco  Tecamachalco        NAB  NAM002
# 247808              Tecamachalco  Tecamachalco        NAB  NAM002
# 247809              Tecamachalco  Tecamachalco        NAB  NAM002
#
#           Descripción Tipo Fecha inicio Recurrencia Digital  Geoefectividad  \
# 0       Preventa Comercial   2025-01-02                  No              45
# ...

# %%
df_final_cliente_class = df_pivot_class[['Fecha inicio','Región Comercial_Act 2026','Nombre UO','Jefatura_y','Ruta','Descripción Tipo','Recurrencia Digital','Id cliente','Geoeficiencia','Geoefectividad','Hora de llegada','Tiempo de atencion','Pedido Omnicanal']]

df_final_cliente_class = df_final_cliente_class[df_final_cliente_class['Recurrencia Digital'] == 'Si']
df_final_cliente_class = df_final_cliente_class.rename(columns={'Jefatura_y': 'Jefatura'})

df_final_cliente_class.to_parquet('bdd_mrk_cp_class.parquet')

df_final_cliente_class.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30720 entries, 1 to 247260
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Fecha inicio               30720 non-null  datetime64[ns]
#  1   Región Comercial_Act 2026  30720 non-null  object
#  2   Nombre UO                  30720 non-null  object
#  3   Jefatura                   30720 non-null  object
#  4   Ruta                       30720 non-null  object
#  5   Descripción Tipo           30720 non-null  object
#  6   Recurrencia Digital        30720 non-null  object
#  7   Id cliente                 30720 non-null  int64
#  8   Geoeficiencia              30720 non-null  int64
#  9   Geoefectividad             30720 non-null  int64
#  10  Hora de llegada            30720 non-null  object
#  11  Tiempo de atencion         30720 non-null  timedelta64[ns]
#  12  Pedido Omnicanal           30720 non-null  int64
# ...

# %%
df_mrk_cp_class
# Out:
#                      Zona                Región Gerencia Jefatura_x    Ruta  \
# 0         CENTRO-PACIFICO          TECAMACHALCO     NA01        NA6  NA0028
# 1         CENTRO-PACIFICO          TECAMACHALCO     NA01        NA6  NA0028
# 2         CENTRO-PACIFICO          TECAMACHALCO     NA01        NA6  NA0028
# 3         CENTRO-PACIFICO          TECAMACHALCO     NA01        NA6  NA0028
# 4         CENTRO-PACIFICO          TECAMACHALCO     NA01        NA6  NA0028
# ...                   ...                   ...      ...        ...     ...
# 11596400  CENTRO-PACIFICO  CHILAPA-CHILPANCINGO     HW01        HW1  HW0197
# 11596401  CENTRO-PACIFICO  CHILAPA-CHILPANCINGO     HW01        HW1  HW0199
# 11596402  CENTRO-PACIFICO              ACAPULCO     CJ01        CJ2  CJ0011
# 11596403  CENTRO-PACIFICO  CHILAPA-CHILPANCINGO     HV01        HV3  HV0103
# 11596404  CENTRO-PACIFICO  CHILAPA-CHILPANCINGO     HV01        HV3  HV0103
#
# ...

# %%
df_mrk_cp_class.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11596405 entries, 0 to 11596404
# Data columns (total 39 columns):
#  #   Column                                 Dtype
# ---  ------                                 -----
#  0   Zona                                   object
#  1   Región                                 object
#  2   Gerencia                               object
#  3   Jefatura_x                             object
#  4   Ruta                                   object
#  5   Id cliente                             int64
#  6   Cliente_x                              object
#  7   Canal                                  object
#  8   GEC                                    object
#  9   Fecha inicio                           datetime64[ns]
#  10  Pedido                                 int64
#  11  Distancia de llegada al cliente (mts)  float64
#  12  Distancia de salida al cliente (mts)   float64
#  13  Hora de llegada                        datetime64[ns]
# ...

# %%
# 🧾 Columnas a considerar
columns = [
    'Región Comercial_Act 2026', 'Nombre UO', 'Jefatura_y', 'Ruta', 'Descripción Tipo',
    'Id cliente', 'Cliente_x', 'Recurrencia Digital', 'Canal', 'GEC', 'Fecha inicio',
    'Distancia de llegada al cliente (mts)', 'Distancia de salida al cliente (mts)',
    'Hora de llegada', 'Hora de salida', 'Fuera de frecuencia',
    'Geoeficiencia', 'Geoefectividad', 'Tiempo de atencion', 'Pedido Digital'
]

# 📋 Crear copia del DataFrame base para evitar SettingWithCopyWarning
df_printable = df_mrk_cp_class[columns].copy()

# 🕒 Convertir columnas de hora a datetime con formato explícito
df_printable['Hora de llegada'] = pd.to_datetime(
    df_printable['Hora de llegada'],
    format='%Y-%m-%d %H:%M:%S',
    errors='coerce'
)

# 🕓 Mostrar solo HH:MM:SS
df_printable['Hora de llegada'] = df_printable['Hora de llegada'].dt.strftime('%H:%M:%S')

# ⏱️ Convertir tiempo de atención a formato timedelta
df_printable['Tiempo de atencion'] = pd.to_timedelta(df_printable['Tiempo de atencion'], unit='ms')

# 💻 Filtrar solo los clientes con recurrencia digital
df_printable = df_printable[df_printable['Recurrencia Digital'] == 'Si']

# 🕒 Mostrar solo HH:MM:SS en Tiempo de atención (sin "0 days")
df_printable['Tiempo de atencion'] = df_printable['Tiempo de atencion'].apply(
    lambda x: str(x).split(' days ')[-1].split('.')[0] if pd.notnull(x) else None
)

inicio = '2025-10-01'
fin = '2025-11-15'

df_filtrado = df_printable[
    (df_printable['Fecha inicio'] >= inicio) &
    (df_printable['Fecha inicio'] <= fin)
]

# 📅 Ordenar por Fecha, Región, UO, Jefatura, Ruta y Hora de llegada
df_filtrado = df_filtrado.sort_values(
    by=['Fecha inicio', 'Región Comercial_Act 2026', 'Nombre UO', 'Jefatura_y', 'Ruta', 'Hora de llegada'],
    ascending=[True, True, True, True, True, True]
).reset_index(drop=True)

# 📊 Resultado final
df_filtrado
# Out:
#      Región Comercial_Act 2026     Nombre UO Jefatura_y    Ruta  \
# 0                     Acapulco        Cayaco        CJ1  CJ0011
# 1                     Acapulco        Cayaco        CJ1  CJ0106
# 2                     Acapulco        Cayaco        CJ2  CJ0038
# 3                     Acapulco        Cayaco        CJ2  CJ0039
# 4                     Acapulco        Cayaco        CJ2  CJ0040
# ...                        ...           ...        ...     ...
# 5824              Tecamachalco  Tecamachalco        NA1  NAFA02
# 5825              Tecamachalco  Tecamachalco        NA2  NA0027
# 5826              Tecamachalco  Tecamachalco        NA3  NA0047
# 5827              Tecamachalco  Tecamachalco        NA6  NA0003
# 5828              Tecamachalco  Tecamachalco        NA6  NA0004
#
#         Descripción Tipo  Id cliente              Cliente_x  \
# 0     Preventa Comercial  1920104041   MISC. TODO AMERICANO
# 1     Preventa Comercial  1920009185     Misc Ramses Aldair
# ...

# %%
import pandas as pd
from openpyxl import load_workbook
from openpyxl.styles import Font, PatternFill, Alignment, Border, Side

# 📁 Nombre del archivo de salida
ruta_salida = "Reporte_Recurrencia_Digital.xlsx"

# ✍️ Exportar a Excel (sin estilo)
df_filtrado.to_excel(ruta_salida, index=False, sheet_name="Recurrencia Digital")

# 📚 Cargar el archivo con openpyxl para aplicar estilo
wb = load_workbook(ruta_salida)
ws = wb.active

# 🎨 Estilos
header_fill = PatternFill(start_color="C00000", end_color="C00000", fill_type="solid")  # Rojo Coca-Cola
header_font = Font(color="FFFFFF", bold=True, name="Calibri", size=11)
center_align = Alignment(horizontal="center", vertical="center")
border_style = Border(
    left=Side(border_style="thin", color="D9D9D9"),
    right=Side(border_style="thin", color="D9D9D9"),
    top=Side(border_style="thin", color="D9D9D9"),
    bottom=Side(border_style="thin", color="D9D9D9"),
)

# 🧱 Aplicar formato a los encabezados
for cell in ws[1]:
    cell.fill = header_fill
    cell.font = header_font
    cell.alignment = center_align
    cell.border = border_style

# 📏 Ajustar ancho automático de columnas
for column_cells in ws.columns:
    length = max(len(str(cell.value)) if cell.value is not None else 0 for cell in column_cells)
    adjusted_width = length + 2
    ws.column_dimensions[column_cells[0].column_letter].width = adjusted_width

# ❄️ Congelar la fila de encabezado
ws.freeze_panes = "A2"

# 💾 Guardar el archivo final
wb.save(ruta_salida)

print(f"✅ Reporte generado con formato ejecutivo: {ruta_salida}")
# Out:
# ✅ Reporte generado con formato ejecutivo: Reporte_Recurrencia_Digital.xlsx
